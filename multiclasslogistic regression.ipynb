# %% [markdown]
# import numpy as np
# import pandas as pd

# %%
import numpy as np
import pandas as pd

# %%
class multilogisticregression:
  def __init__(self,lr=0.01,n_iter=1000,reg_lambda=0.1):
    self.lr=lr
    self.n_iter=n_iter
    self.theta=None
    
    self.reg_lambda=reg_lambda
  def sigmoid(self,X):
    return 1/(1+np.exp(-X))
  def onevsall(self,z):
    return self.sigmoid(z)
    #X=a,b  Y=a,k(num classes)

  
  def fit(self,X,Y,num_classes):
    
    X = (X - np.mean(X,axis=0))/(np.std(X,axis=0))
    samples,features=X.shape
    Ycopy=Y
    Y=np.eye(num_classes)[Y]
    Ycopy=Y

    self.theta=np.random.randn(features,num_classes)
    costs=[]
    acc=[]


    for i in range(self.n_iter):
      y_hat=self.onevsall(X.dot(self.theta))



      loss=(-1/samples)*(np.sum(Y*np.log(y_hat))) + (1/(2*samples))*(self.reg_lambda)*np.sum(self.theta[1:]**2)
      grads = (1/samples)*np.dot(X.T,(y_hat-Y))+(self.reg_lambda/samples)*np.vstack([np.zeros((1,num_classes)),self.theta[1:]])


      self.theta -= self.lr*grads
      costs.append(loss)
      if(i%100==0):
        acc=self.accuracy(X,Ycopy)
        print(f"no of iters{i},acc is{acc}")






    def accuracy(self,X,Y):
        Y_pred = self.pred(X)
        return np.mean(Y==Y_pred)
    def pred(self,X):
        X = (X - np.mean(X,axis=0))/(np.std(X,axis=0))
        Yh = self.softmax(np.dot(X,self.theta))
        return  np.argmax(y_hat,axis=1)

# %%
a=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/classification_train.csv')
x=np.array(a)

X_train=(x[:10000,2:])/256
Y_train=(x[:10000,1:2])
model= multilogisticregression(lr=.01, n_iter=1000,reg_lambda=0.01)
model.fit(X_train,Y_train,10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-386de7457ef5> in <module>
#       5 Y_train=(x[:10000,1:2])
#       6 model= multilogisticregression(lr=.01, n_iter=1000,reg_lambda=0.01)
# ----> 7 model.fit(X_train,Y_train,10)
#
# <ipython-input-3-8ffa1dcfc955> in fit(self, X, Y, num_classes)
#      32
#      33       loss=(-1/samples)*(np.sum(Y*np.log(y_hat))) + (1/(2*samples))*(self.reg_lambda)*np.sum(self.theta[1:]**2)
# ---> 34       grads = (1/samples)*np.dot(X.T,(y_hat-Y))+(self.reg_lambda/samples)*np.vstack([np.zeros((1,num_classes)),self.theta[1:]])
#      35
#      36
#
# ValueError: operands could not be broadcast together with shapes (784,10000,10) (784,10)
